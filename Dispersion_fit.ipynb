# %% [markdown]
# В этом блокноте фитируется $\epsilon(\omega)$ по коэффициентам отражения и пропускания графена разной толщины на полипропиленовой плёнке в зависимости от частоты

# %% [markdown]
# Основная проблема - выбор числа точек для фитинга, чтобы минимизировать случайную погрешность и изменение $\epsilon(\omega)$

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import optimize
import pandas as pd
import glob
import os

# %% [markdown]
# прочитать файлы записать в переменные

# %%
# Load data using configurable paths

def load_data(file_path):
    return pd.read_csv(file_path, sep='\t', decimal=',')

base_path_r = r'C:\Users\belco\Documents\Graphene\Data\Dispersion_PP_40\Ref_dis'
base_path_t = r'C:\Users\belco\Documents\Graphene\Data\Dispersion_PP_40\Transm_dis'

re_paths = {
    're_PP': os.path.join(base_path_r, r'PP_layer_reflectance_45_deg_0.dpt'),
    're_0_5l': os.path.join(base_path_r, r'PP+graphene-0.5_layer_reflectance_45_deg_0.dpt'),
    're_1l': os.path.join(base_path_r, r'PP+graphene-1_layer_reflectance_45_deg_0.dpt'),
    're_2l': os.path.join(base_path_r, r'PP+graphene-2_layers_reflectance_45_deg_0.dpt'),
    're_3l': os.path.join(base_path_r, r'PP+graphene-3_layers_reflectance_45_deg_0.dpt'),
    're_4l': os.path.join(base_path_r, r'PP+graphene-4_layers_reflectance_45_deg_0.dpt'),
    're_5l': os.path.join(base_path_r, r'PP+graphene-5_layers_reflectance_45_deg_1_0.dpt')
}

re_PP   = load_data(re_paths['re_PP'])
re_0_5l = load_data(re_paths['re_0_5l'])
re_1l   = load_data(re_paths['re_1l'])
re_2l   = load_data(re_paths['re_2l'])
re_3l   = load_data(re_paths['re_3l'])
re_4l   = load_data(re_paths['re_4l'])
re_5l   = load_data(re_paths['re_5l'])

tr_paths = {
    'tr_PP':     os.path.join(base_path_t, r'PP-40 um_transmittance.0.dpt'),
    'tr_0_5l':   os.path.join(base_path_t, r'PP-40 um+graphene-0.5L_transmittance.0.dpt'),
    'tr_0_5l_1': os.path.join(base_path_t, r'PP-40 um+graphene-0.5L_transmittance_1.0.dpt'),
    'tr_1l':     os.path.join(base_path_t, r'PP-40 um+graphene-1L_transmittance.0.dpt'),    
    'tr_2l':     os.path.join(base_path_t, r'PP-40 um+graphene-2L_transmittance.0.dpt'), 
    'tr_3l':     os.path.join(base_path_t, r'PP-40 um+graphene-3L_transmittance.0.dpt'),
    'tr_4l':     os.path.join(base_path_t, r'PP-40 um+graphene-4L_transmittance.0.dpt'),
    'tr_5l':     os.path.join(base_path_t, r'PP-40 um+graphene-5L_transmittance.0.dpt'),

}


tr_PP =  load_data(tr_paths['tr_PP'])
tr_0_5l =load_data(tr_paths['tr_0_5l'])
tr_1l =  load_data(tr_paths['tr_1l'])
tr_2l =  load_data(tr_paths['tr_2l'])
tr_3l =  load_data(tr_paths['tr_3l'])
tr_4l =  load_data(tr_paths['tr_4l'])
tr_5l =  load_data(tr_paths['tr_5l'])
# Out:
# C:\Users\belco\Documents\Graphene\Data\Dispersion_PP_40\Ref_dis\PP_layer_reflectance_45_deg_0.dpt

# %%
os.getcwd()
# Out:
# 'c:\\Users\\belco\\Documents\\Graphene\\Graphene-films-plasmon-refractometry'

# %%
r_0_5 =
r_1 =
r_3_5 =
r_6 =
r_12 =


tr_0_5 =
tr_1 = 
tr_3_5 = 
tr_6 =
tr_12 =
